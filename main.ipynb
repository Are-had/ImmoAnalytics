# %%
import pandas as pd

# %%
df=pd.read_csv('data/ValeursFoncieres-2020-S2.txt', sep='|')
# Out:
# C:\Users\arezk\AppData\Local\Temp\ipykernel_7428\1182889806.py:1: DtypeWarning: Columns (14,18,23,24,26,28,31,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('data/ValeursFoncieres-2020-S2.txt', sep='|')

# %%
df.head()
# Out:
#    Identifiant de document  Reference document  1 Articles CGI  \
# 0                      NaN                 NaN             NaN
# 1                      NaN                 NaN             NaN
# 2                      NaN                 NaN             NaN
# 3                      NaN                 NaN             NaN
# 4                      NaN                 NaN             NaN
#
#    2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    No disposition Date mutation Nature mutation  ...  \
# 0               1    01/07/2020           Vente  ...
# 1               1    01/07/2020           Vente  ...
# ...

# %%
print(len(df.columns))
# Out:
# 43
